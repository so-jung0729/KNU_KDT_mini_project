# %% [markdown]
# ## 대주제: 경제 지표에 따른 사회 현상
# ### 세부 주제: 경기에 따른 부동산 매매가격, 전세가격 변화
# * 1조 이소정
# *  1인당 국민총소득(GNI)는 경기를 나타내는 지표 중 하나로, GNI가 변화하는 것에 따른 부동산 매매가격 지수, 전세가격 지수의 변화가 나타나는 가에 대해 알아봤습니다.
# * **데이터**
# >* GNI 데이터: 우리나라 국민이 국내는 물론 국외에서 벌어들인 소득의 실질구매력을 나타내는 지표로 실질 GDP에서 외국인이 국내에서 벌어간 실질소득은 차감하고 우리 국민이 국외에서 벌어들인 실질소득은 더하여 산출했다.
#     출처: 통계청 https://www.index.go.kr/unify/idx-info.do?idxCd=4221
# >* 주택 매매가격 지수 및 전세가격 지수: 전국 주택시장의 매매, 전세, 월세가격을 조사하여 주택시장의 평균적인 가격변화를 측정,
# 2021년 6월을 데이터를 100으로 두고 계산하였다.
#     출처: 한국부동산원 https://www.reb.or.kr/r-one/statistics/statisticsViewer.do?menuId=HOUSE_21111

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### GNI 데이터 가져오기

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\sojnl\anaconda3\lib\site-packages (3.0.10)
# Requirement already satisfied: et_xmlfile in c:\users\sojnl\anaconda3\lib\site-packages (from openpyxl) (1.1.0)

# %%
df1 = pd.read_excel('./data/GNI_excel.xlsx', header=2, index_col=1, nrows = 4) # 2번 째 행에서 1행부터 4개열 들고오기
df1
# Out:
# C:\Users\sojnl\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#         Unnamed: 0      2004      2005      2006      2007      2008  \
# 명목/원화   1인당 GNI 2)   1,886.1   1,973.0   2,070.0   2,232.6   2,353.5
# 명목/달러화         NaN  16,476.9  19,261.8  21,663.7  24,026.8  21,345.3
# 실질/원화          NaN   2,331.5   2,383.0   2,464.9   2,592.0   2,582.2
# 증가율 3)         NaN       3.9       2.2       3.4       5.2      -0.4
#
#             2009      2010      2011      2012      2013      2014      2015  \
# 명목/원화    2,440.7   2,673.0   2,798.6   2,898.8   2,995.1   3,094.8   3,260.2
# 명목/달러화  19,122.1  23,117.7  25,255.8  25,723.7  27,351.3  29,383.9  28,813.6
# 실질/원화    2,632.6   2,808.3   2,832.1   2,899.7   2,997.5   3,082.8   3,260.2
# 증가율 3)       2.0       6.7       0.8       2.4       3.4       2.8       5.8
#
#             2016      2017      2018      2019      2020      2021
# 명목/원화    3,411.2   3,588.6   3,693.0   3,753.9   3,776.6   4,048.2
# 명목/달러화  29,394.3  31,734.1  33,563.7  32,204.4  32,004.1  35,373.1
# 실질/원화    3,390.7   3,492.5   3,530.9   3,532.4   3,529.5   3,656.2
# 증가율 3)       4.0       3.0       1.1       0.0      -0.1       3.6

# %%
#  df1 정보확인
print(df1.info(), df1.index, df1.columns, sep = '\n\n')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 명목/원화 to 증가율 3)
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1 non-null      object
#  1   2004        4 non-null      object
#  2   2005        4 non-null      object
#  3   2006        4 non-null      object
#  4   2007        4 non-null      object
#  5   2008        4 non-null      object
#  6   2009        4 non-null      object
#  7   2010        4 non-null      object
#  8   2011        4 non-null      object
#  9   2012        4 non-null      object
#  10  2013        4 non-null      object
#  11  2014        4 non-null      object
#  12  2015        4 non-null      object
#  13  2016        4 non-null      object
#  14  2017        4 non-null      object
#  15  2018        4 non-null      object
#  16  2019        4 non-null      object
#  17  2020        4 non-null      object
#  18  2021        4 non-null      object
# dtypes: object(19)
# memory usage: 640.0+ bytes
# None
#
# Index(['명목/원화', '명목/달러화', '실질/원화', '증가율 3)'], dtype='object')
#
# Index(['Unnamed: 0', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
#        '2020', '2021'],
#       dtype='object')

# %% [markdown]
# * 연도에 따른 실질 GNI 지수 저장

# %%
gni_df = df1.iloc[2, 1:].reset_index().rename(columns = {'index' : 'year', '실질/원화': 'gni'})
gni_df
# Out:
#     year      gni
# 0   2004  2,331.5
# 1   2005  2,383.0
# 2   2006  2,464.9
# 3   2007  2,592.0
# 4   2008  2,582.2
# 5   2009  2,632.6
# 6   2010  2,808.3
# 7   2011  2,832.1
# 8   2012  2,899.7
# 9   2013  2,997.5
# 10  2014  3,082.8
# 11  2015  3,260.2
# 12  2016  3,390.7
# 13  2017  3,492.5
# 14  2018  3,530.9
# 15  2019  3,532.4
# 16  2020  3,529.5
# 17  2021  3,656.2

# %% [markdown]
# GNI 데이터가 object로 수치 데이터로 변경

# %%
gni_df.gni = gni_df.gni.apply(lambda x: float(x.replace(',', '')))
gni_df
# Out:
#     year     gni
# 0   2004  2331.5
# 1   2005  2383.0
# 2   2006  2464.9
# 3   2007  2592.0
# 4   2008  2582.2
# 5   2009  2632.6
# 6   2010  2808.3
# 7   2011  2832.1
# 8   2012  2899.7
# 9   2013  2997.5
# 10  2014  3082.8
# 11  2015  3260.2
# 12  2016  3390.7
# 13  2017  3492.5
# 14  2018  3530.9
# 15  2019  3532.4
# 16  2020  3529.5
# 17  2021  3656.2

# %% [markdown]
# #### 부동산 매매가격지수 데이터 가져오기

# %%
df2 = pd.read_excel('./data/월간_매매가격지수_종합.xlsx',header=10) 
df2.head(15)
# Out:
#       지 역 Unnamed: 1 Unnamed: 2 Unnamed: 3  2003년 11월  2003년 12월  2004년 01월  \
# 0      전국        NaN        NaN        NaN  61.451824  60.963185  60.652009
# 1     수도권        NaN        NaN        NaN  55.765538  55.359195  55.116437
# 2     지방권        NaN        NaN        NaN  68.358856  67.760797    67.3565
# 3   6대광역시        NaN        NaN        NaN  60.555931  59.922991  59.557162
# 4   5대광역시        NaN        NaN        NaN   61.78014  61.119917  60.744738
# 5     9개도        NaN        NaN        NaN  64.674855  64.251678  63.889014
# 6     8개도        NaN        NaN        NaN   73.67135  73.203488  72.782257
# 7      서울        NaN        NaN        NaN   55.60303  55.203394  55.054587
# 8     NaN       강북지역        NaN        NaN   55.20276  54.930934   54.90227
# 9     NaN        NaN        도심권        NaN          -          -          -
# 10    NaN        NaN        NaN        종로구  64.000432  63.452239  64.252497
# 11    NaN        NaN        NaN         중구  62.081273  61.670009  62.087912
# 12    NaN        NaN        NaN        용산구  43.687959  43.225348  43.367363
# 13    NaN        NaN        동북권        NaN          -          -          -
# 14    NaN        NaN        NaN        성동구  59.940139  59.867408  59.923491
#
#     2004년 02월  2004년 03월  2004년 04월  ...   2022년 02월   2022년 03월   2022년 04월  \
# 0   60.743829  60.842376  60.935649  ...  104.750185  104.768133  104.829612
# 1   55.228958  55.376448  55.511443  ...  106.096471  106.054496  106.085391
# 2   67.416319  67.441927   67.47331  ...  103.564452  103.634568  103.722689
# 3   59.574504  59.636041  59.685955  ...  104.478175  104.419594  104.394368
# 4   60.787542  60.892069  60.948611  ...  103.583307  103.519435  103.482909
# 5   63.958864  64.005253  64.075325  ...  105.334923  105.404159  105.519014
# 6   72.862986  72.773203  72.766869  ...  103.728561  103.895962  104.073241
# 7   55.275343  55.505539   55.69095  ...  103.583137  103.574493  103.613995
# 8   55.006509  55.142714  55.243353  ...  103.252702  103.221158  103.248619
# 9           -          -          -  ...  103.232335  103.248188  103.360658
# 10  64.347619  63.705956  63.847436  ...  102.686401  102.663392  102.758526
# 11  62.226387  62.431914  62.275199  ...  102.605009  102.569690  102.618450
# 12  43.681338  44.339855  45.001861  ...  103.907111  103.974625  104.130969
# 13          -          -          -  ...  103.321652  103.277271  103.289838
# 14   60.28969  60.888701  61.275857  ...  102.163744  102.157418  102.167230
#
#      2022년 05월   2022년 06월   2022년 07월   2022년 08월   2022년 09월   2022년 10월  \
# 0   104.844014  104.837210  104.758261  104.459050  103.949855  103.148521
# 1   106.047282  106.000446  105.847246  105.421458  104.742401  103.674704
# 2   103.782879  103.811013  103.796938  103.608525  103.248399  102.681709
# 3   104.289894  104.167698  103.989532  103.527370  102.811406  101.810075
# 4   103.396330  103.281525  103.131796  102.735104  102.076980  101.179429
# 5   105.585167  105.638540  105.614851  105.385020  104.973341  104.279677
# 6   104.235149  104.366141  104.448806  104.406776  104.252356  103.909726
# 7   103.657903  103.654227  103.565486  103.314026  102.831331  102.003517
# 8   103.287196  103.279065  103.131792  102.800653  102.262153  101.451524
# 9   103.480579  103.538915  103.524626  103.370483  102.979217  102.328873
# 10  102.859414  102.912771  102.897288  102.718157  102.292286  101.851980
# 11  102.643081  102.630745  102.483772  102.077216  101.446627  100.601365
# 12  104.312026  104.409716  104.464036  104.455845  104.210739  103.521776
# 13  103.314330  103.303478  103.129825  102.764195  102.198933  101.308528
# 14  102.185755  102.202161  102.190805  102.144580  101.994214  101.494471
#
#      2022년 11월
# 0   101.736171
# 1   101.838685
# 2   101.644873
# 3   100.043103
# 4    99.630710
# 5   103.026256
# 6   103.218563
# 7   100.639836
# 8   100.041091
# 9   101.442975
# 10  101.173330
# 11   99.333482
# 12  102.696580
# 13   99.661530
# 14  100.431304
#
# [15 rows x 233 columns]

# %% [markdown]
# #### 부동산 전세가격지수 데이터 가져오기

# %%
df3 = pd.read_excel('./data/월간_전세가격지수_종합.xlsx', header = 10)
df3.head(15)
# Out:
#       지 역 Unnamed: 1 Unnamed: 2 Unnamed: 3  2003년 12월  2004년 01월  2004년 02월  \
# 0      전국        NaN        NaN        NaN  59.575331  59.209691   59.30727
# 1     수도권        NaN        NaN        NaN  53.381388  52.998164  53.078503
# 2     지방권        NaN        NaN        NaN  66.518315  66.193285  66.312755
# 3   6대광역시        NaN        NaN        NaN  60.423033   59.92439  59.967838
# 4   5대광역시        NaN        NaN        NaN  62.114685  61.649051  61.717534
# 5     9개도        NaN        NaN        NaN  60.717331  60.437234  60.583966
# 6     8개도        NaN        NaN        NaN  69.916648  69.801014  69.985416
# 7      서울        NaN        NaN        NaN  54.716491  54.381342  54.458411
# 8     NaN       강북지역        NaN        NaN  55.969754  55.544732  55.539828
# 9     NaN        NaN        도심권        NaN          -          -          -
# 10    NaN        NaN        NaN        종로구  68.061542  67.945693  67.457378
# 11    NaN        NaN        NaN         중구  58.728183  58.772919  58.744284
# 12    NaN        NaN        NaN        용산구  61.455354  61.512794  62.130232
# 13    NaN        NaN        동북권        NaN          -          -          -
# 14    NaN        NaN        NaN        성동구  51.717684  51.794381  51.979591
#
#     2004년 03월  2004년 04월  2004년 05월  ...   2022년 02월   2022년 03월   2022년 04월  \
# 0   59.466954  59.514041  59.362426  ...  103.249443  103.230765  103.236549
# 1   53.244122  53.249467  53.025346  ...  103.982781  103.895104  103.866768
# 2   66.457653  66.564598  66.525896  ...  102.600072  102.642125  102.677967
# 3   60.110615  60.176017  60.021967  ...  103.025092  102.901168  102.802714
# 4    61.88707  61.986271  61.875552  ...  102.590340  102.509347  102.406738
# 5   60.792111  60.873452  60.799786  ...  103.598943  103.658734  103.735883
# 6   70.090979  70.204298  70.264519  ...  102.745324  102.895660  103.036626
# 7   54.550512  54.513918  54.235206  ...  102.706196  102.646089  102.609949
# 8   55.610712  55.631936  55.375973  ...  102.512896  102.455629  102.432549
# 9           -          -          -  ...  102.268806  102.178689  102.111186
# 10  65.993596  66.136599  66.170853  ...  102.303840  102.234479  102.131646
# 11  59.317733  59.488023  58.775821  ...  102.415222  102.311043  102.239010
# 12  62.212145  62.682358  62.694374  ...  102.172586  102.076002  102.033765
# 13          -          -          -  ...  102.586771  102.541854  102.547463
# 14  52.393189   52.71848  52.902441  ...  102.034145  101.985366  102.012322
#
#      2022년 05월   2022년 06월   2022년 07월   2022년 08월   2022년 09월   2022년 10월  \
# 0   103.233453  103.209187  103.123228  102.837952  102.327543  101.425319
# 1   103.842949  103.797600  103.662013  103.255555  102.553070  101.285404
# 2   102.693137  102.687462  102.645292  102.467106  102.126915  101.550208
# 3   102.645678  102.429101  102.182559  101.677428  100.949468   99.868166
# 4   102.256441  102.067831  101.851510  101.430981  100.768273   99.775736
# 5   103.817366  103.890463  103.885323  103.674518  103.260934  102.472735
# 6   103.176426  103.304191  103.387884  103.380348  103.265850  102.969304
# 7   102.602661  102.586250  102.509825  102.348890  101.891527  100.909743
# 8   102.402225  102.369712  102.294053  102.131097  101.715941  100.851160
# 9   102.074453  102.010984  101.931496  101.735762  101.348015  100.443854
# 10  102.067481  101.994908  101.923948  101.694159  101.299201  100.486310
# 11  102.220783  102.211203  102.126188  101.911874  101.316662  100.429619
# 12  102.005627  101.921108  101.838833  101.674583  101.395587  100.423336
# 13  102.536905  102.523940  102.461592  102.329406  101.947227  101.069855
# 14  102.046727  102.085377  102.060280  101.950829  101.680331  100.968367
#
#      2022년 11월
# 0    99.856381
# 1    99.077302
# 2   100.556053
# 3    98.050936
# 4    98.142464
# 5   101.112801
# 6   102.405915
# 7    99.055575
# 8    99.172795
# 9    99.082281
# 10   99.559510
# 11   98.832891
# 12   98.897498
# 13   99.267294
# 14   99.274380
#
# [15 rows x 232 columns]

# %%
# 전국의 주택 매매 가격 지수 가져오기
sale = df2.iloc[0, 4:].to_frame().reset_index().rename(columns = {'index':'year', 0:'sale'})
sale
# Out:
#           year        sale
# 0    2003년 11월   61.451824
# 1    2003년 12월   60.963185
# 2    2004년 01월   60.652009
# 3    2004년 02월   60.743829
# 4    2004년 03월   60.842376
# ..         ...         ...
# 224  2022년 07월  104.758261
# 225  2022년 08월   104.45905
# 226  2022년 09월  103.949855
# 227  2022년 10월  103.148521
# 228  2022년 11월  101.736171
#
# [229 rows x 2 columns]

# %%
# 전국의 주택 전세 가격 지수 가져오기
charter = df3.iloc[0, 4:].to_frame().reset_index().rename(columns = {'index':'year', 0:'char'})
charter
# Out:
#           year        char
# 0    2003년 12월   59.575331
# 1    2004년 01월   59.209691
# 2    2004년 02월    59.30727
# 3    2004년 03월   59.466954
# 4    2004년 04월   59.514041
# ..         ...         ...
# 223  2022년 07월  103.123228
# 224  2022년 08월  102.837952
# 225  2022년 09월  102.327543
# 226  2022년 10월  101.425319
# 227  2022년 11월   99.856381
#
# [228 rows x 2 columns]

# %%
# 주택 가격에 관한 데이터를 하나의 데이터프레임으로 변환
house = pd.merge(sale, charter)
house
# Out:
#           year        sale        char
# 0    2003년 12월   60.963185   59.575331
# 1    2004년 01월   60.652009   59.209691
# 2    2004년 02월   60.743829    59.30727
# 3    2004년 03월   60.842376   59.466954
# 4    2004년 04월   60.935649   59.514041
# ..         ...         ...         ...
# 223  2022년 07월  104.758261  103.123228
# 224  2022년 08월   104.45905  102.837952
# 225  2022년 09월  103.949855  102.327543
# 226  2022년 10월  103.148521  101.425319
# 227  2022년 11월  101.736171   99.856381
#
# [228 rows x 3 columns]

# %%
# 정보확인
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 228 entries, 0 to 227
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    228 non-null    object
#  1   sale    228 non-null    object
#  2   char    228 non-null    object
# dtypes: object(3)
# memory usage: 7.1+ KB

# %%
# 연도 뽑기
house.year = house.year.apply(lambda x: x[:4])

# 매매 및 전세 데이터 타입 변경
house[['sale', 'char']] = house[['sale', 'char']].astype('float64')
house
# Out:
#      year        sale        char
# 0    2003   60.963185   59.575331
# 1    2004   60.652009   59.209691
# 2    2004   60.743829   59.307270
# 3    2004   60.842376   59.466954
# 4    2004   60.935649   59.514041
# ..    ...         ...         ...
# 223  2022  104.758261  103.123228
# 224  2022  104.459050  102.837952
# 225  2022  103.949855  102.327543
# 226  2022  103.148521  101.425319
# 227  2022  101.736171   99.856381
#
# [228 rows x 3 columns]

# %%
# 정보확인
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 228 entries, 0 to 227
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    228 non-null    object
#  1   sale    228 non-null    float64
#  2   char    228 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 7.1+ KB

# %% [markdown]
# ![image.png](attachment:image.png)
# https://www.reb.or.kr/r-one/statistics/statisticsViewer.do?menuId=HOUSE_21111
#
# 주택 매매 및 전세 가격 지수는 월별 데이터로 년간 데이터로 변경 시, 한국부동산원에서 권장한 주택가격동향 계산 방법은 기하평균이다.

# %%
import statistics as st
# st.geometric_mean(list_values) 기하평균 값들을 곱한 뒤 루트를 씌운 값

y, s, c = [], [], []                    # year, sale, charter
for i in range(2004, 2022):
    y.append(str(i))
    h = house[house.year == str(i)]
    s.append(st.geometric_mean(h.sale))
    c.append(st.geometric_mean(h.char))

# %%
# 리스트 정보확인
print(y, len(y))
print(s, len(s))
print(c, len(c))
# Out:
# ['2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'] 18
# [60.429505728866744, 60.72042461374813, 64.32713379369024, 71.22541433947217, 76.23084137539591, 77.10885695066271, 78.83645953119704, 82.41983923079086, 83.96065325795139, 82.89956036590208, 84.10434609628173, 86.33847894304232, 87.948797076428, 88.945111925013, 90.20689448382032, 90.02018907547335, 92.56551398174356, 100.39539319016923] 18
# [58.2377054692459, 56.779507864791874, 59.628052098694596, 63.20105989041464, 65.9782106254169, 66.39513670731888, 70.43309908951335, 78.02215289454371, 81.92772058059438, 84.31912825565601, 88.16471055810071, 91.70571656932626, 94.35354263187776, 95.25793495168736, 94.57702245564961, 92.67553429344306, 94.23219961426753, 100.39136684515964] 18

# %%
# 연도별 지수를 계산한 데이터로 데이터 프레임 만들기
house_3 = pd.DataFrame({'year': y, 'sale':s, 'char': c})
house_3
# Out:
#     year        sale        char
# 0   2004   60.429506   58.237705
# 1   2005   60.720425   56.779508
# 2   2006   64.327134   59.628052
# 3   2007   71.225414   63.201060
# 4   2008   76.230841   65.978211
# 5   2009   77.108857   66.395137
# 6   2010   78.836460   70.433099
# 7   2011   82.419839   78.022153
# 8   2012   83.960653   81.927721
# 9   2013   82.899560   84.319128
# 10  2014   84.104346   88.164711
# 11  2015   86.338479   91.705717
# 12  2016   87.948797   94.353543
# 13  2017   88.945112   95.257935
# 14  2018   90.206894   94.577022
# 15  2019   90.020189   92.675534
# 16  2020   92.565514   94.232200
# 17  2021  100.395393  100.391367

# %%
house_3.info()
gni_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    18 non-null     object
#  1   sale    18 non-null     float64
#  2   char    18 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 560.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    18 non-null     object
#  1   gni     18 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 416.0+ bytes

# %%
# gni와 주택 지수의 데이터 합치기
total = pd.merge(gni_df, house_3)
total
# Out:
#     year     gni        sale        char
# 0   2004  2331.5   60.429506   58.237705
# 1   2005  2383.0   60.720425   56.779508
# 2   2006  2464.9   64.327134   59.628052
# 3   2007  2592.0   71.225414   63.201060
# 4   2008  2582.2   76.230841   65.978211
# 5   2009  2632.6   77.108857   66.395137
# 6   2010  2808.3   78.836460   70.433099
# 7   2011  2832.1   82.419839   78.022153
# 8   2012  2899.7   83.960653   81.927721
# 9   2013  2997.5   82.899560   84.319128
# 10  2014  3082.8   84.104346   88.164711
# 11  2015  3260.2   86.338479   91.705717
# 12  2016  3390.7   87.948797   94.353543
# 13  2017  3492.5   88.945112   95.257935
# 14  2018  3530.9   90.206894   94.577022
# 15  2019  3532.4   90.020189   92.675534
# 16  2020  3529.5   92.565514   94.232200
# 17  2021  3656.2  100.395393  100.391367

# %%
# GNI, 주택매매가격지수, 주택전세가격지수의 분포
fig, ax1 = plt.subplots(figsize = (20, 10))
ax2 = ax1.twinx()

ax1.plot(total.year, total.gni, 'ro-', label = 'GNI')
ax2.plot(total.year, total.sale, 'bo-', label ='sale')
ax2.plot(total.year, total.char, 'yo-', label = 'char')

ax1.set_ylabel('gni', labelpad=15)
ax2.set_ylabel('index', labelpad=15)

ax1.set_xlabel('Year', labelpad=15)

ax2.set_ylim(50, 110)

ax1.grid(axis = 'x')

ax2.legend(loc = 'upper left')

plt.title('GNI, HOUSE INDEX')

plt.show()

# %% [markdown]
# * gni에 따른 부동산 가격 변동

# %%
total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    18 non-null     object
#  1   gni     18 non-null     float64
#  2   sale    18 non-null     float64
#  3   char    18 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 720.0+ bytes

# %%
# GNI와 주택전세가격 지수의 산점도 
import matplotlib.pyplot as plt

plt.scatter(total.gni, total.sale)
plt.xlabel('GNI')
plt.ylabel('SALE INDEX')
plt.title('house sale index of GNI')
plt.show()

# %%
# GNI와 주택전세가격 지수의 산점도 
plt.scatter(total.gni, total.char)
plt.xlabel('GNI')
plt.ylabel('CHAR INDEX')
plt.title('house char index of GNI')
plt.show()

# %%
# 상관관계 분석
cor = total.corr(method='pearson')
cor
# Out:
#            gni      sale      char
# gni   1.000000  0.938932  0.975619
# sale  0.938932  1.000000  0.949660
# char  0.975619  0.949660  1.000000

# %% [markdown]
# * **GNI**와 **주택매매가격지수**의 상관관계를 분석한 결과 상관계수가 0.938932으로 상관정도가 매우 높게 나왔습니다.
#     - GNI가 높아질수록 주택매매가격지수 또한 높아집니다.
#
# * **GNI**와 **주택전세가격지수**의 상관관계를 분석한 결과 상관계수가 0.0.975619 상관정도가 매우 높게 나왔습니다.
#     - GNI가 높아질수록 주택전세가격지수 또한 높아집니다.
# <br/><br/>
# ▶ 경기가 안좋으면 부동산을 매매와 전세 시 부담높고, 경기가 좋아지면 상대적으로 매매, 전세 시 부담이 적어진다

# %% [markdown]
# 범죄, 자살 상관X
# 물가, 자동차,
